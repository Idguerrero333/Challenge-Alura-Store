# %% [markdown]
# <a href="https://colab.research.google.com/github/Idguerrero333/Challenge-Alura-Store/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
type(tienda)
# Out:
# pandas.core.frame.DataFrame

# %%
tienda.shape ##explorando el dataframe visualizando numero de filas y columnas
# Out:
# (2359, 12)

# %%
tienda.columns ## explorando el dataframe visualizando el nombre de las columnas
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
tienda.info() ## informacion de las columnas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda.describe(include='all') ## estadisticas de las columnas
# Out:
#           Producto Categoría del Producto        Precio  Costo de envío  \
# count         2359                   2359  2.359000e+03     2359.000000
# unique          51                      8           NaN             NaN
# top     Microondas                Muebles           NaN             NaN
# freq            60                    465           NaN             NaN
# mean           NaN                    NaN  4.878679e+05    26018.609580
# std            NaN                    NaN  6.146868e+05    32860.001783
# min            NaN                    NaN  7.600000e+03        0.000000
# 25%            NaN                    NaN  5.575000e+04     3100.000000
# 50%            NaN                    NaN  2.353000e+05    12400.000000
# 75%            NaN                    NaN  6.781000e+05    36000.000000
# max            NaN                    NaN  2.977000e+06   160800.000000
#
#        Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# ...

# %%
tienda4.isnull().sum()
# Out:
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %%
tienda.sample(10)
# Out:
#                        Producto   Categoría del Producto     Precio  \
# 893             Cubo mágico 8x8                 Juguetes    15200.0
# 2002            Olla de presión  Artículos para el hogar    89900.0
# 303                    Smart TV             Electrónicos  1687000.0
# 2019         Guitarra eléctrica   Instrumentos musicales   693000.0
# 1700           Secadora de ropa        Electrodomésticos   995400.0
# 3                    Microondas        Electrodomésticos   757500.0
# 1432          Guitarra acústica   Instrumentos musicales   357500.0
# 1678         Guitarra eléctrica   Instrumentos musicales   667700.0
# 1460                 Cubertería  Artículos para el hogar    35700.0
# 986   Carrito de control remoto                 Juguetes    87000.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 893           1500.0      18/04/2021   Juan Fernandez     Bucaramanga
# 2002          5000.0      05/11/2020  Mariana Herrera     Santa Marta
# ...

# %%
tienda['lat'] #validando tipo de datos por columna
# Out:
# 0        4.60971
# 1        6.25184
# 2       10.39972
# 3        3.43722
# 4        6.25184
#           ...
# 2354     6.25184
# 2355     4.60971
# 2356     3.43722
# 2357     1.21361
# 2358     3.43722
# Name: lat, Length: 2359, dtype: float64

# %%
tienda.Producto.value_counts() #contando valores por columna
# Out:
# Producto
# Microondas                     60
# TV LED UHD 4K                  60
# Armario                        60
# Secadora de ropa               58
# Mesa de noche                  56
# Bloques de construcción        56
# Balón de baloncesto            55
# Bicicleta                      54
# Vaso térmico                   54
# Refrigerador                   54
# Impresora                      54
# Batería                        53
# Cubertería                     52
# Carrito de control remoto      52
# Modelado predictivo            51
# Auriculares                    50
# Ajedrez de madera              49
# Iphone 15                      49
# Lavavajillas                   48
# Lavadora de ropa               47
# Guitarra eléctrica             47
# Guitarra acústica              46
# Sofá reclinable                46
# Silla de oficina               46
# Estufa                         45
# Cama box                       44
# Kit de bancas                  44
# ...

# %%
tienda.Producto.value_counts(normalize=True)*100 #porcentaje de sobre cada producto
# Out:
# Producto
# Microondas                     2.543451
# TV LED UHD 4K                  2.543451
# Armario                        2.543451
# Secadora de ropa               2.458669
# Mesa de noche                  2.373887
# Bloques de construcción        2.373887
# Balón de baloncesto            2.331496
# Bicicleta                      2.289106
# Vaso térmico                   2.289106
# Refrigerador                   2.289106
# Impresora                      2.289106
# Batería                        2.246715
# Cubertería                     2.204324
# Carrito de control remoto      2.204324
# Modelado predictivo            2.161933
# Auriculares                    2.119542
# Ajedrez de madera              2.077151
# Iphone 15                      2.077151
# Lavavajillas                   2.034760
# Lavadora de ropa               1.992370
# Guitarra eléctrica             1.992370
# Guitarra acústica              1.949979
# Sofá reclinable                1.949979
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
tienda.groupby('Producto').mean(numeric_only=True) # promedio por tipo de propiedad de todas las columnas con datos numericos
# Out:
#                                    Precio  Costo de envío  Calificación  \
# Producto
# Ajedrez de madera            2.919592e+04     1691.836735      4.428571
# Armario                      4.910383e+05    26068.333333      3.950000
# Asistente virtual            2.014500e+05    10620.000000      4.075000
# Auriculares                  1.008740e+05     5694.000000      3.640000
# Auriculares con micrófono    1.433576e+05     8221.212121      3.969697
# Balón de baloncesto          4.999636e+04     2560.000000      3.872727
# Balón de voleibol            5.029048e+04     2440.476190      4.071429
# Batería                      7.112057e+05    37956.603774      4.188679
# Bicicleta                    5.082333e+05    26827.777778      3.944444
# Bloques de construcción      3.331607e+04     1644.642857      4.089286
# Cama box                     5.021523e+05    26277.272727      4.113636
# Cama king                    7.085591e+05    37884.090909      3.772727
# ...

# %%
porcentaje_producto = tienda.Producto.value_counts(normalize=True).to_frame()*100
porcentaje_producto.plot(kind='bar', figsize=(12,8), color='green', xlabel='Tipos', ylabel='Porcentaje')
# Out:
# <Axes: xlabel='Tipos', ylabel='Porcentaje'>

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# # 5. Envío promedio por tienda
